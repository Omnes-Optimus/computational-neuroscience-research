# %% [markdown]
# # Global Order data, Local Order data and Node community data extraction
#
#
# 1. Extract Global Order Data
# 2. Extract Local Order Data
# 3. Store in data folder
# 4. Obtain node community data

# %%
# %reload_ext autoreload
# %autoreload 2

from tes.data_ingestion import DataRead
from tes.algo_umap import UmapAlgo
from tes.DataUtils import DataUtils

# %% [markdown]
# #### Create objects to access built in functions

# %%
ext = DataRead()
analyse=UmapAlgo()
deg_obj = DataUtils()
# Out:
# ../../data/connectivity_matrix/mb_communities.npz already exists
# DataUtils initialized

# %% [markdown]
# #### Extract global order and local order

# %%
ext.new_algo_ext(2,"raw/itr_3.bz2", "raw/loc_3.bz2")
# Out:
# Current iteration is 0
# ../../data/connectivity_matrix/mb_communities.npz already exists
# DataUtils initialized
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 ext.new_algo_ext(2,"raw/itr_3.bz2", "raw/loc_3.bz2")
#
# File ~/srg-networks-tes-nimish/analysis/tes/data_ingestion.py:193, in DataRead.new_algo_ext(self, itr_c, itr_filename, loc_filename)
#     183 print("Current iteration is", c)
#     184 mbn = MBN_RC(
#     185     nepochs=40000,
#     186     dt=0.05,
#    (...)
#     190     plot_bifurcation=False,
#     191 )
# --> 193 mbn.run_model()
#     195 # df to store 1 iteration data
#     196 df = pd.DataFrame(mbn.GLOBAL_ORDER_VERBOSE)
#
# File ~/srg-networks-tes-nimish/analysis/tes/MBN_Res_Constrn.py:81, in MBN_RC.run_model(self)
#      80 def run_model(self):
# ---> 81     tES_Adaptive.run_model(self)
#
# File ~/srg-networks-tes-nimish/analysis/tes/tES_Adaptive.py:109, in tES_Adaptive.run_model(self)
#     104 if i%2000 == 0:
#     105     #print(f'LAMBDA_O={self.LAMBDA_O}, Global Order(R)={self.GLOBAL_ORDER}')
#     106     pass
# --> 109 wts = np.sum(np.multiply(self.A.T, np.sin(self.THETA.T - self.THETA)), axis=1)
#     110 coupling = np.multiply(self.LAMBDA, np.multiply(self.ADAPTIVE_COUPLING, wts))
#     111 dTHETA = (self.NAT_FREQ + coupling) * self.DT
#
# KeyboardInterrupt:

# %% [markdown]
# #### Read the data

# %%
df = ext.data_read_bz2('raw/itr_3.bz2')
df.shape

# %% [markdown]
# Find start and stop points of detected transitions

# %%
# in simulation number 1, there are 2 visible transitions
dict_points=analyse.compute_parameters(df[1])

# %% [markdown]
# Visusalize them

# %%
analyse.plot_transition(df[1],dict_points['start_points'],dict_points['stop_points'])

# %%
df_loc=ext.data_read_bz2("raw/loc_3.bz2")
df_loc

# %% [markdown]
# #### Extract node community data

# %%
ext.ext_node_community(df_loc,0.5,'raw/nc_test.bz2')

# %%
df_nc=ext.data_read_bz2('raw/nc_test.bz2')
df_nc

# %%
#1st transiton data
df_nc.loc[1][0:5000]

# %%
#2nd transition data
df_nc.loc[1][5000:10000]
